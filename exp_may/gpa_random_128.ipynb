# %% [markdown]
# <a href="https://colab.research.google.com/github/allnes/age_classifier/blob/master/exp_may/gpa_random_128.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Connect to Google Drive

# %%
# %tensorflow_version 1.x

from google.colab import drive
import os

drive.mount('/content/drive')
os.chdir('/content/drive/My Drive/DL_DATA_GRAPH/BUILD/cnn_graph/')
# !ls

# !git clone https://github.com/mdeff/cnn_graph
# !git status
# !git fetch
# !git checkout graph_train
# !git pull origin graph_train


# %run age_classifier/age_classes_coarsening \
  --path_project='/content/drive/My Drive/DL_DATA_GRAPH/' \
  --path_data='NEW/converted_data_resize_875_gpa_random_128.npz' \
  --zip_size=128

# %matplotlib inline
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# age_classifier	LICENSE.txt  rcv1.ipynb        summaries
# checkpoints	makefile     README.md	       trials
# lib		nips2016     requirements.txt  usage.ipynb
# From https://github.com/allnes/cnn_graph
#  * branch            graph_train -> FETCH_HEAD
# Already up to date.
# ['arr_0', 'arr_1']
# (729, 16384)
# (729,)
# --> Reshape data
# [0 1 2 3 4 5 6 7 8]
# --> Get distance graph
# d = |V| = 128, k|V| < |E| = 105828
# --> Get laplacian matrix
# Layer 0: M_0 = |V| = 24464 nodes (8080 added),|E| = 52914 edges
# Layer 1: M_1 = |V| = 12232 nodes (3587 added),|E| = 28213 edges
# Layer 2: M_2 = |V| = 6116 nodes (968 added),|E| = 19055 edges
# Layer 3: M_3 = |V| = 3058 nodes (0 added),|E| = 13102 edges
# (583, 24464)
# (36, 24464)
# (110, 24464)
# NN architecture
#   input: M_0 = 24464
#   layer 1: cgconv1
#     representation: M_0 * F_1 / p_1 = 24464 * 32 / 4 = 195712
#     weights: F_0 * F_1 * K_1 = 1 * 32 * 16 = 512
#     biases: M_1 * F_1 = 24464 * 32 = 782848
#   layer 2: cgconv2
#     representation: M_1 * F_2 / p_2 = 6116 * 32 / 2 = 97856
#     weights: F_1 * F_2 * K_2 = 32 * 32 * 16 = 16384
#     biases: M_2 * F_2 = 6116 * 32 = 195712
#   layer 3: fc1
#     representation: M_3 = 2000
#     weights: M_2 * M_3 = 97856 * 2000 = 195712000
#     biases: M_3 = 2000
#   layer 4: logits (softmax)
#     representation: M_4 = 9
#     weights: M_3 * M_4 = 2000 * 9 = 18000
#     biases: M_4 = 9
# step 100 / 1166 (epoch 2.74 / 32):
#   learning_rate = 9.03e-04, loss_average = 3.82e+02
#   validation accuracy: 22.22 (8 / 36), f1 (weighted): 19.57, loss: 5.23e+02
#   time: 1113s (wall 65s)
# step 200 / 1166 (epoch 5.49 / 32):
#   learning_rate = 7.74e-04, loss_average = 3.81e+02
#   validation accuracy: 13.89 (5 / 36), f1 (weighted): 11.85, loss: 5.23e+02
#   time: 2215s (wall 143s)
# step 300 / 1166 (epoch 8.23 / 32):
#   learning_rate = 6.63e-04, loss_average = 3.80e+02
#   validation accuracy: 8.33 (3 / 36), f1 (weighted): 8.06, loss: 5.22e+02
#   time: 3299s (wall 219s)
# step 400 / 1166 (epoch 10.98 / 32):
#   learning_rate = 5.99e-04, loss_average = 3.80e+02
#   validation accuracy: 13.89 (5 / 36), f1 (weighted): 13.13, loss: 5.21e+02
#   time: 4396s (wall 296s)
# step 500 / 1166 (epoch 13.72 / 32):
#   learning_rate = 5.13e-04, loss_average = 3.80e+02
#   validation accuracy: 11.11 (4 / 36), f1 (weighted): 10.98, loss: 5.21e+02
#   time: 5472s (wall 371s)
# step 600 / 1166 (epoch 16.47 / 32):
#   learning_rate = 4.40e-04, loss_average = 3.80e+02
#   validation accuracy: 16.67 (6 / 36), f1 (weighted): 15.77, loss: 5.21e+02
#   time: 6547s (wall 448s)
# step 700 / 1166 (epoch 19.21 / 32):
#   learning_rate = 3.77e-04, loss_average = 3.79e+02
#   validation accuracy: 19.44 (7 / 36), f1 (weighted): 17.81, loss: 5.21e+02
#   time: 7618s (wall 524s)
# step 800 / 1166 (epoch 21.96 / 32):
#   learning_rate = 3.41e-04, loss_average = 3.79e+02
#   validation accuracy: 22.22 (8 / 36), f1 (weighted): 19.19, loss: 5.21e+02
#   time: 8693s (wall 600s)
# step 900 / 1166 (epoch 24.70 / 32):
#   learning_rate = 2.92e-04, loss_average = 3.79e+02
#   validation accuracy: 16.67 (6 / 36), f1 (weighted): 15.77, loss: 5.21e+02
#   time: 9766s (wall 677s)
# step 1000 / 1166 (epoch 27.44 / 32):
#   learning_rate = 2.50e-04, loss_average = 3.79e+02
#   validation accuracy: 22.22 (8 / 36), f1 (weighted): 19.19, loss: 5.21e+02
#   time: 10834s (wall 753s)
# step 1100 / 1166 (epoch 30.19 / 32):
#   learning_rate = 2.15e-04, loss_average = 3.79e+02
#   validation accuracy: 22.22 (8 / 36), f1 (weighted): 19.19, loss: 5.21e+02
#   time: 11898s (wall 829s)
# step 1166 / 1166 (epoch 32.00 / 32):
#   learning_rate = 2.04e-04, loss_average = 3.79e+02
#   validation accuracy: 16.67 (6 / 36), f1 (weighted): 15.77, loss: 5.21e+02
#   time: 12619s (wall 886s)
# validation accuracy: peak = 22.22, mean = 16.94
# Time per step: 771.78 ms
# (110, 24464) (110,)
# ############ Class 0
# (16, 24464)
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/DL_DATA_GRAPH/BUILD/cnn_graph/lib/../checkpoints/demo/model-1166
# accuracy: 37.50 (6 / 16), f1 (weighted): 54.55, loss: 3.82e+02
# time: 4s (wall 1s)
# ############ Class 1
# (9, 24464)
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/DL_DATA_GRAPH/BUILD/cnn_graph/lib/../checkpoints/demo/model-1166
# accuracy: 11.11 (1 / 9), f1 (weighted): 20.00, loss: 6.88e+02
# time: 4s (wall 1s)
# ############ Class 2
# (10, 24464)
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/DL_DATA_GRAPH/BUILD/cnn_graph/lib/../checkpoints/demo/model-1166
# accuracy: 30.00 (3 / 10), f1 (weighted): 46.15, loss: 6.14e+02
# time: 4s (wall 1s)
# ############ Class 3
# (23, 24464)
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/DL_DATA_GRAPH/BUILD/cnn_graph/lib/../checkpoints/demo/model-1166
# accuracy: 30.43 (7 / 23), f1 (weighted): 46.67, loss: 5.40e+02
# time: 7s (wall 2s)
# ############ Class 4
# (8, 24464)
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/DL_DATA_GRAPH/BUILD/cnn_graph/lib/../checkpoints/demo/model-1166
# accuracy: 25.00 (2 / 8), f1 (weighted): 40.00, loss: 7.72e+02
# time: 4s (wall 1s)
# ############ Class 5
# (15, 24464)
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/DL_DATA_GRAPH/BUILD/cnn_graph/lib/../checkpoints/demo/model-1166
# accuracy: 6.67 (1 / 15), f1 (weighted): 12.50, loss: 4.30e+02
# time: 4s (wall 1s)
# ############ Class 6
# (15, 24464)
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/DL_DATA_GRAPH/BUILD/cnn_graph/lib/../checkpoints/demo/model-1166
# accuracy: 6.67 (1 / 15), f1 (weighted): 12.50, loss: 4.32e+02
# time: 4s (wall 1s)
# ############ Class 7
# (13, 24464)
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/DL_DATA_GRAPH/BUILD/cnn_graph/lib/../checkpoints/demo/model-1166
# accuracy: 15.38 (2 / 13), f1 (weighted): 26.67, loss: 4.93e+02
# time: 4s (wall 1s)
# ############ Class 8
# (1, 24464)
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/DL_DATA_GRAPH/BUILD/cnn_graph/lib/../checkpoints/demo/model-1166
# accuracy: 0.00 (0 / 1), f1 (weighted): 0.00, loss: 6.08e+03
# time: 4s (wall 1s)
# ############ All
# INFO:tensorflow:Restoring parameters from /content/drive/My Drive/DL_DATA_GRAPH/BUILD/cnn_graph/lib/../checkpoints/demo/model-1166
# accuracy: 20.91 (23 / 110), f1 (weighted): 20.37, loss: 4.02e+02
# time: 20s (wall 3s)
