# %% [markdown]
# <a href="https://colab.research.google.com/github/allnes/age_classifier/blob/master/exp_may/gpa_hard_128.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Connect to Google Drive

# %%
# %tensorflow_version 1.x

from google.colab import drive
import os

drive.mount('/content/drive')
os.chdir('/content/drive/My Drive/DL_DATA_GRAPH/BUILD/cnn_graph/')
# !ls

# !git clone https://github.com/mdeff/cnn_graph
# !git status
# !git fetch
# !git checkout graph_train
# !git pull origin graph_train


# %run age_classifier/age_classes_coarsening \
  --path_project='/content/drive/My Drive/DL_DATA_GRAPH/' \
  --path_data='NEW/converted_data_resize_875_gpa_hard_128.npz' \
  --zip_size=128

# %matplotlib inline
# Out:
# TensorFlow 1.x selected.
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# age_classifier	LICENSE.txt  rcv1.ipynb        summaries
# checkpoints	makefile     README.md	       trials
# lib		nips2016     requirements.txt  usage.ipynb
# From https://github.com/allnes/cnn_graph
#  * branch            graph_train -> FETCH_HEAD
# Already up to date.
# ['arr_0', 'arr_1']
# (729, 16384)
# (729,)
# --> Reshape data
# [0 1 2 3 4 5 6 7 8]
# --> Get distance graph
# d = |V| = 128, k|V| < |E| = 107012
# ...
