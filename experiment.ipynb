# %% [markdown]
# <a href="https://colab.research.google.com/github/allnes/age_classifier/blob/master/experiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Connect to Google Drive

# %%
# %tensorflow_version 1.x

from google.colab import drive
import os

drive.mount('/content/drive')
os.chdir('/content/drive/My Drive/DL_DATA_GRAPH/BUILD/cnn_graph/')
# !ls

# !git clone https://github.com/mdeff/cnn_graph
# !git status
# !git fetch
# !git checkout graph_train
# !git pull origin graph_train


# %run age_classifier/9_classes \
  --path_project='/content/drive/My Drive/DL_DATA_GRAPH/' \
  --zip_size=128

# %matplotlib inline
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# age_classifier	LICENSE.txt  rcv1.ipynb        summaries
# checkpoints	makefile     README.md	       trials
# lib		nips2016     requirements.txt  usage.ipynb
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 8 (delta 4), reused 8 (delta 4), pack-reused 0
# Unpacking objects: 100% (8/8), done.
# From https://github.com/allnes/cnn_graph
#  * branch            graph_train -> FETCH_HEAD
#    4f952df..c7a43b8  graph_train -> origin/graph_train
# Updating 4f952df..c7a43b8
# Fast-forward
#  age_classifier/9_classes.py | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)
# ['arr_0', 'arr_1']
# (729, 16384)
# (729,)
# --> Reshape data
# [0 1 2 3 4 5 6 7 8]
# --> Get distance graph
# d = |V| = 128, k|V| < |E| = 128470
# --> Get laplacian matrix
# ...
